# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/CS\ 598\ MLSWE/CS598JBR-Team-27\ Drive/CS598JBR-Team-27
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/CS 598 MLSWE/CS598JBR-Team-27 Drive/CS598JBR-Team-27
# /content/drive/MyDrive/CS 598 MLSWE/CS598JBR-Team-27 Drive/CS598JBR-Team-27
# CS598JBR-Team-27-MP1.ipynb  human-eval	MP2
# CS598JBR-Team-27-MP2.ipynb  MP1		README.md

# %%
#sujay

# %cd drive/MyDrive/CS598JBR-Team-27\ Drive/CS598JBR-Team-27/MP2



# !pwd
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1nDHjHffV_Q_dXMz5cYmkE4qSrEy2es6K/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP2
# /content/drive/.shortcut-targets-by-id/1nDHjHffV_Q_dXMz5cYmkE4qSrEy2es6K/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP2
# commands.py
# Coverage
# HumanEval_109.py
# HumanEval_109_test.py
# HumanEval_112.py
# HumanEval_112_test.py
# HumanEval_119.py
# HumanEval_119_test.py
# HumanEval_134.py
# HumanEval_134_test.py
# HumanEval_142.py
# HumanEval_142_test.py
# HumanEval_143.py
# HumanEval_143_test.py
# HumanEval_145.py
# HumanEval_145_test.py
# HumanEval_147.py
# HumanEval_147_test.py
# HumanEval_152.py
# HumanEval_152_test.py
# HumanEval_36.py
# HumanEval_36_test.py
# HumanEval_39.py
# HumanEval_39_test.py
# HumanEval_3.py
# HumanEval_3_test.py
# HumanEval_4.py
# HumanEval_4_test.py
# HumanEval_64.py
# HumanEval_64_test.py
# HumanEval_76.py
# HumanEval_76_test.py
# HumanEval_78.py
# HumanEval_78_test.py
# HumanEval_84.py
# HumanEval_84_test.py
# HumanEval_92.py
# ...

# %%
# TODO: Update Your NetIDs in alphabetical order
NetIDs = ["pranavn6", "mns9", "mae10", "snh6"]
NetIDs_str = " ".join(NetIDs)
print(NetIDs_str)
# TODO: Clone your GitHub repository
# ! git clone https://github.com/Intelligent-CAT-Lab/CS598JBR-Team-0.git
# Out:
# pranavn6 mns9 mae10 snh6

# %%
# Set up requirements for model prompting
! bash -x MP2/setup_models.sh
# Out:
# + pip3 install bitsandbytes==0.47.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 14.8 MB/s eta 0:00:00
# ...
# + pip3 install transformers==4.55.4
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 89.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 69.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ...
# + pip3 install peft==0.4.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: peft
#     Found existing installation: peft 0.17.1
#     Uninstalling peft-0.17.1:
# ...

# %%
# !pwd
# %cd MP2/
seed = "272469978654662835334249905214610999505"
# TODO: Replace the file path of selected_humaneval_[seed].jsonl generated in previous step
input_dataset = "selected_humaneval_" + seed + ".jsonl"
print(input_dataset)
# Out:
# /content/drive/MyDrive/CS 598 MLSWE/CS598JBR-Team-27 Drive/CS598JBR-Team-27
# /content/drive/MyDrive/CS 598 MLSWE/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP2
# selected_humaneval_272469978654662835334249905214610999505.jsonl

# %%
task_1_vanilla_json = "task_1_" + seed + "_vanilla.jsonl"

# Prompt the models
! python3 task_1.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_1_vanilla_json} "True" |& tee task_1_vanilla.log
# Out:
# 2025-10-20 20:55:11.726278: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760993711.760072   60334 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760993711.769995   60334 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760993711.793455   60334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
task_1_crafted_json = "task_1_" + seed + "_crafted.jsonl"

# Prompt the models
! python3 task_1.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_1_crafted_json} "False" |& tee task_1_crafted.log
# Out:
# 2025-10-21 17:13:00.153180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761066780.173950   20920 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761066780.180648   20920 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761066780.197272   20920 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# TEST TASK 2 CODE

# %%
# !pip uninstall -y bitsandbytes
# !pip install bitsandbytes==0.43.0
# !pip install transformers==4.36.0
# !pip install jsonlines
# Out:
# WARNING: Skipping bitsandbytes as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 130.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %cd /content/drive/.shortcut-targets-by-id/1nDHjHffV_Q_dXMz5cYmkE4qSrEy2es6K/CS598JBR-Team-27\ Drive/CS598JBR-Team-27/MP2
# !pwd
# !ls -la
# Out:
# /content/drive/.shortcut-targets-by-id/1nDHjHffV_Q_dXMz5cYmkE4qSrEy2es6K/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP2
# /content/drive/.shortcut-targets-by-id/1nDHjHffV_Q_dXMz5cYmkE4qSrEy2es6K/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP2
# total 271
# -rw------- 1 root root  1678 Oct 20 16:22 commands.py
# drwx------ 2 root root  4096 Oct 16 20:53 Coverage
# -rw------- 1 root root   133 Oct 21 22:54 HumanEval_76.py
# -rw------- 1 root root  1312 Oct 21 22:54 HumanEval_76_test.py
# -rw------- 1 root root   699 Oct 21 22:54 HumanEval_95.py
# -rw------- 1 root root  1489 Oct 21 22:54 HumanEval_95_test.py
# drwx------ 2 root root  4096 Oct 20 22:12 .ipynb_checkpoints
# drwx------ 2 root root  4096 Oct 21 22:51 __pycache__
# drwx------ 3 root root  4096 Oct 21 22:51 .pytest_cache
# -rw------- 1 root root 30777 Oct 20 16:25 selected_humaneval_272469978654662835334249905214610999505.jsonl
# -rw------- 1 root root   263 Oct 16 22:41 setup_models.sh
# ...

# %%
task_2_vanilla_json = "task_2_" + seed + "_vanilla.jsonl"

# Prompt the models
! python3 task_2.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_2_vanilla_json} "True" |& tee task_2_vanilla.log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4209120643.py in <cell line: 0>()
# ----> 1 task_2_vanilla_json = "task_2_" + seed + "_vanilla.jsonl"
#       2
#       3 # Prompt the models
#       4 get_ipython().system(' python3 task_2.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_2_vanilla_json} "True" |& tee task_2_vanilla.log')
#
# NameError: name 'seed' is not defined

# %%
task_2_crafted_json = "task_2_" + seed + "_crafted.jsonl"

# Prompt the models
! python3 task_2.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_2_crafted_json} "False" |& tee task_2_crafted.log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2224123115.py in <cell line: 0>()
# ----> 1 task_2_crafted_json = "task_2_" + seed + "_crafted.jsonl"
#       2
#       3 # Prompt the models
#       4 get_ipython().system(' python3 task_2.py {input_dataset} "deepseek-ai/deepseek-coder-6.7b-instruct" {task_2_crafted_json} "False" |& tee task_2_crafted.log')
#
# NameError: name 'seed' is not defined

# %%
# Push outputs to github repo

# %%
# ! pip install jsonlines
# !pwd
# %cd MP1
! python3 make_table.py
# Out:
# /content/drive/MyDrive/CS598JBR-Team-27 Drive/CS598JBR-Team-27
# /content/drive/MyDrive/CS598JBR-Team-27 Drive/CS598JBR-Team-27/MP1
#  comparison_table.csv and comparison_table.md written
